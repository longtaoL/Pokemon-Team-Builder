# %%
# !pip install efficient-apriori

# %%
from efficient_apriori import apriori
transactions = [('eggs', 'bacon', 'soup'),
                ('eggs', 'bacon', 'apple'),
                ('soup', 'bacon', 'banana')]
itemsets, rules = apriori(transactions, min_support=0.1, min_confidence=0.5, max_length=2, output_transaction_ids=True)
print(itemsets)
print(rules)
# Out:
# {1: {('eggs',): ItemsetCount(itemset_count=2, members={0, 1}), ('bacon',): ItemsetCount(itemset_count=3, members={0, 1, 2}), ('soup',): ItemsetCount(itemset_count=2, members={0, 2}), ('apple',): ItemsetCount(itemset_count=1, members={1}), ('banana',): ItemsetCount(itemset_count=1, members={2})}, 2: {('apple', 'bacon'): ItemsetCount(itemset_count=1, members={1}), ('apple', 'eggs'): ItemsetCount(itemset_count=1, members={1}), ('bacon', 'banana'): ItemsetCount(itemset_count=1, members={2}), ('bacon', 'eggs'): ItemsetCount(itemset_count=2, members={0, 1}), ('bacon', 'soup'): ItemsetCount(itemset_count=2, members={0, 2}), ('banana', 'soup'): ItemsetCount(itemset_count=1, members={2}), ('eggs', 'soup'): ItemsetCount(itemset_count=1, members={0})}}
# [{apple} -> {bacon}, {eggs} -> {apple}, {apple} -> {eggs}, {banana} -> {bacon}, {eggs} -> {bacon}, {bacon} -> {eggs}, {soup} -> {bacon}, {bacon} -> {soup}, {soup} -> {banana}, {banana} -> {soup}, {soup} -> {eggs}, {eggs} -> {soup}]

# %%
trans = [
('Landorus-Therian', 'Slowbro', 'Tornadus-Therian', 'Heatran', 'Zeraora', 'Melmetal'),
('Clefable', 'Heatran', 'Landorus-Therian', 'Weavile', 'Slowbro', 'Zapdos'),
('Landorus-Therian', 'Tapu Koko', 'Urshifu-*', 'Melmetal', 'Heatran', 'Tornadus-Therian'),
('Slowbro', 'Weavile', 'Heatran', 'Landorus-Therian', 'Tapu Lele', 'Urshifu-*'),
('Zapdos-Galar', 'Garchomp', 'Ferrothorn', 'Tornadus-Therian', 'Tapu Koko', 'Tapu Fini'),
('Dragapult', 'Kartana', 'Bisharp', 'Melmetal', 'Landorus-Therian', 'Weavile'),
('Ferrothorn', 'Weavile', 'Landorus-Therian', 'Victini', 'Urshifu-*', 'Tapu Koko'),
('Kartana', 'Landorus-Therian', 'Magnezone', 'Nihilego', 'Slowbro', 'Weavile'),
('Ninetales-Alola', 'Dragapult', 'Heatran', 'Garchomp', 'Cloyster', 'Scizor'),
('Landorus-Therian', 'Toxapex', 'Tapu Koko', 'Ferrothorn', 'Weavile', 'Slowking-Galar'),
('Bisharp', 'Buzzwole', 'Landorus-Therian', 'Latios', 'Toxapex', 'Zeraora'),
('Tornadus-Therian', 'Ninetales-Alola', 'Landorus-Therian', 'Volcanion', 'Corviknight', 'Arctozolt'),
('Barraskewda', 'Seismitoad', 'Dragonite', 'Volcanion', 'Pelipper', 'Melmetal'),
('Garchomp', 'Blaziken', 'Heatran', 'Dragapult', 'Ninetales-Alola', 'Arctozolt'),
('Landorus-Therian', 'Heatran', 'Weavile', 'Tornadus-Therian', 'Zeraora', 'Slowbro'),
('Ninetales-Alola', 'Volcarona', 'Landorus-Therian', 'Tapu Fini', 'Bisharp', 'Blacephalon'),
('Landorus-Therian', 'Corviknight', 'Tapu Koko', 'Toxapex', 'Weavile', 'Blacephalon'),
('Zeraora', 'Landorus-Therian', 'Heatran', 'Blacephalon', 'Tornadus-Therian', 'Tapu Fini'),
('Dracozolt', 'Slowbro', 'Landorus-Therian', 'Tyranitar', 'Ferrothorn', 'Tornadus-Therian'),
('Pelipper', 'Ferrothorn', 'Moltres-Galar', 'Zapdos', 'Barraskewda', 'Seismitoad'),
('Landorus-Therian', 'Weavile', 'Ferrothorn', 'Zapdos', 'Tapu Fini', 'Blacephalon'),
('Tornadus-Therian', 'Urshifu-*', 'Heatran', 'Landorus-Therian', 'Bisharp', 'Slowbro'),
('Landorus-Therian', 'Ferrothorn', 'Clefable', 'Tyranitar', 'Dragonite', 'Tapu Fini'),
('Tornadus-Therian', 'Ferrothorn', 'Landorus-Therian', 'Tapu Fini', 'Magnezone', 'Clefable'),
('Tornadus-Therian', 'Garchomp', 'Landorus-Therian', 'Magnezone', 'Toxapex', 'Melmetal'),
('Tapu Koko', 'Heatran', 'Landorus-Therian', 'Volcanion', 'Tornadus-Therian', 'Tapu Fini'),
('Weavile', 'Garchomp', 'Volcarona', 'Ferrothorn', 'Tapu Fini', 'Zapdos'),
('Dragapult', 'Corviknight', 'Swampert', 'Kartana', 'Zeraora', 'Kommo-o'),
('Victini', 'Weavile', 'Slowking-Galar', 'Landorus-Therian', 'Corviknight', 'Tapu Fini'),
('Tapu Koko', 'Dragonite', 'Victini', 'Ferrothorn', 'Landorus-Therian', 'Clefable'),
('Dragapult', 'Melmetal', 'Toxapex', 'Tornadus-Therian', 'Landorus-Therian', 'Heatran'),
('Zapdos', 'Urshifu-*', 'Weavile', 'Landorus-Therian', 'Ferrothorn', 'Slowking'),
('Zapdos', 'Toxapex', 'Landorus-Therian', 'Weavile', 'Slowking-Galar', 'Scizor'),
('Kartana', 'Blaziken', 'Nihilego', 'Landorus-Therian', 'Urshifu-*', 'Celesteela'),
('Clefable', 'Corviknight', 'Landorus-Therian', 'Tapu Koko', 'Volcanion', 'Weavile'),
('Tapu Fini', 'Landorus-Therian', 'Hawlucha', 'Nihilego', 'Heatran', 'Celesteela'),
('Garchomp', 'Magnezone', 'Tapu Fini', 'Slowking-Galar', 'Corviknight', 'Weavile'),
('Kartana', 'Tapu Lele', 'Landorus-Therian', 'Melmetal', 'Dragonite', 'Urshifu-*'),
('Arctozolt', 'Tornadus-Therian', 'Garchomp', 'Ferrothorn', 'Ninetales-Alola', 'Blaziken'),
('Dragapult', 'Ferrothorn', 'Landorus-Therian', 'Rotom-Wash', 'Bisharp', 'Tornadus-Therian'),
('Weavile', 'Ferrothorn', 'Zapdos', 'Urshifu-*', 'Tapu Fini', 'Landorus-Therian'),
('Zapdos', 'Melmetal', 'Heatran', 'Landorus-Therian', 'Slowbro', 'Kartana'),
('Kartana', 'Landorus-Therian', 'Magnezone', 'Nihilego', 'Tapu Fini', 'Weavile'),
('Zapdos', 'Toxapex', 'Landorus-Therian', 'Weavile', 'Slowking-Galar', 'Scizor'),
('Weavile', 'Ferrothorn', 'Toxapex', 'Dragapult', 'Garchomp', 'Tornadus-Therian'),
('Glastrier', 'Urshifu-*', 'Landorus-Therian', 'Dragapult', 'Heatran', 'Tapu Lele'),
('Ninetales-Alola', 'Volcarona', 'Landorus-Therian', 'Tapu Fini', 'Bisharp', 'Blacephalon'),
('Suicune', 'Ferrothorn', 'Landorus-Therian', 'Nihilego', 'Weavile', 'Dragapult'),
('Landorus-Therian', 'Toxapex', 'Tapu Koko', 'Ferrothorn', 'Weavile', 'Slowking-Galar'),
('Kartana', 'Landorus-Therian', 'Heatran', 'Zapdos', 'Slowbro', 'Dragapult'),
('Corviknight', 'Garchomp', 'Weavile', 'Slowking-Galar', 'Kartana', 'Urshifu-*'),
('Landorus-Therian', 'Tyranitar', 'Dracozolt', 'Tapu Fini', 'Corviknight', 'Excadrill'),
('Zapdos', 'Weavile', 'Kartana', 'Landorus-Therian', 'Volcanion', 'Melmetal'),
('Tapu Koko', 'Weavile', 'Victini', 'Urshifu-*', 'Landorus-Therian', 'Ferrothorn'),
('Heatran', 'Rillaboom', 'Garchomp', 'Volcarona', 'Hawlucha', 'Weavile'),
('Landorus-Therian', 'Melmetal', 'Heatran', 'Rotom-Wash', 'Weavile', 'Zeraora'),
('Ninetales-Alola', 'Cloyster', 'Moltres-Galar', 'Garchomp', 'Dragapult', 'Heatran'),
('Weavile', 'Victini', 'Clefable', 'Ferrothorn', 'Landorus-Therian', 'Slowbro'),
('Kartana', 'Heatran', 'Zapdos', 'Landorus-Therian', 'Moltres-Galar', 'Tapu Fini'),
('Weavile', 'Landorus-Therian', 'Kartana', 'Blacephalon', 'Melmetal', 'Dragapult'),
('Kartana', 'Landorus-Therian', 'Magnezone', 'Nihilego', 'Slowbro', 'Weavile'),
('Landorus-Therian', 'Volcanion', 'Ferrothorn', 'Heatran', 'Tornadus-Therian', 'Weavile'),
('Clefable', 'Kartana', 'Heatran', 'Slowking', 'Landorus-Therian', 'Weavile'),
('Tapu Koko', 'Victini', 'Tornadus-Therian', 'Ferrothorn', 'Slowbro', 'Landorus-Therian'),
('Heatran', 'Kartana', 'Dragapult', 'Rotom-Wash', 'Clefable', 'Landorus-Therian'),
('Heatran', 'Tornadus-Therian', 'Toxapex', 'Dragapult', 'Landorus-Therian', 'Melmetal'),
('Landorus-Therian', 'Corviknight', 'Tapu Koko', 'Toxapex', 'Weavile', 'Victini'),
('Dragonite', 'Landorus-Therian', 'Slowbro', 'Weavile', 'Blissey', 'Melmetal'),
('Slowking-Galar', 'Landorus-Therian', 'Zapdos', 'Heatran', 'Weavile', 'Tapu Fini'),
('Landorus-Therian', 'Melmetal', 'Slowbro', 'Volcanion', 'Tornadus-Therian', 'Weavile'),
('Slowbro', 'Tapu Koko', 'Buzzwole', 'Heatran', 'Landorus-Therian', 'Bisharp'),
('Dragonite', 'Tapu Koko', 'Clefable', 'Slowking-Galar', 'Ferrothorn', 'Landorus-Therian'),
('Landorus-Therian', 'Dragapult', 'Melmetal', 'Volcanion', 'Tapu Lele', 'Zapdos'),
('Zeraora', 'Weavile', 'Zapdos-Galar', 'Landorus-Therian', 'Slowbro', 'Ferrothorn'),
('Zeraora', 'Zapdos-Galar', 'Jirachi', 'Landorus-Therian', 'Tapu Fini', 'Tornadus-Therian'),
('Landorus-Therian', 'Melmetal', 'Rotom-Wash', 'Heatran', 'Clefable', 'Dragapult'),
('Ferrothorn', 'Tornadus-Therian', 'Excadrill', 'Tyranitar', 'Dracozolt', 'Slowbro'),
('Landorus-Therian', 'Heatran', 'Volcanion', 'Venusaur', 'Torkoal', 'Weavile'),
('Zeraora', 'Weavile', 'Melmetal', 'Landorus-Therian', 'Heatran', 'Slowbro'),
('Heatran', 'Kartana', 'Landorus-Therian', 'Tapu Fini', 'Weavile', 'Zeraora'),
('Garchomp', 'Clefable', 'Kartana', 'Landorus-Therian', 'Magnezone', 'Tapu Fini'),
('Weavile', 'Zapdos', 'Clefable', 'Ferrothorn', 'Landorus-Therian', 'Tapu Fini'),
('Garchomp', 'Weavile', 'Ferrothorn', 'Rotom-Wash', 'Tapu Fini', 'Tornadus-Therian'),
('Tapu Koko', 'Dragonite', 'Victini', 'Ferrothorn', 'Landorus-Therian', 'Clefable'),
('Heatran', 'Tapu Fini', 'Dragonite', 'Landorus-Therian', 'Weavile', 'Kartana'),
('Weavile', 'Landorus-Therian', 'Aegislash', 'Tapu Lele', 'Dragapult', 'Urshifu-*'),
('Dragonite', 'Tapu Koko', 'Buzzwole', 'Heatran', 'Ferrothorn', 'Garchomp'),
('Kartana', 'Volcanion', 'Melmetal', 'Dragapult', 'Landorus-Therian', 'Weavile'),
('Tapu Koko', 'Ferrothorn', 'Tornadus-Therian', 'Heatran', 'Landorus-Therian', 'Tapu Fini'),
('Slowbro', 'Zapdos-Galar', 'Weavile', 'Landorus-Therian', 'Tapu Koko', 'Melmetal'),
('Ferrothorn', 'Tapu Fini', 'Volcarona', 'Zapdos', 'Landorus-Therian', 'Weavile'),
('Weavile', 'Zapdos', 'Landorus-Therian', 'Volcanion', 'Clefable', 'Ferrothorn'),
('Urshifu-*', 'Toxapex', 'Slowking-Galar', 'Landorus-Therian', 'Weavile', 'Corviknight'),
('Heatran', 'Landorus-Therian', 'Hawlucha', 'Tapu Fini', 'Nihilego', 'Celesteela'),
('Landorus-Therian', 'Clefable', 'Tapu Koko', 'Slowking-Galar', 'Dragonite', 'Ferrothorn'),
('Landorus-Therian', 'Dragonite', 'Clefable', 'Heatran', 'Ferrothorn', 'Tapu Koko'),
('Zapdos-Galar', 'Mew', 'Heatran', 'Landorus-Therian', 'Tapu Fini', 'Zeraora'),
('Zeraora', 'Buzzwole', 'Clefable', 'Slowking-Galar', 'Dragonite', 'Ferrothorn'),
('Landorus-Therian', 'Tapu Lele', 'Ferrothorn', 'Tapu Fini', 'Dragonite', 'Weavile'),
('Tornadus-Therian', 'Landorus-Therian', 'Volcanion', 'Zeraora', 'Melmetal', 'Corviknight'),
('Weavile', 'Tornadus-Therian', 'Landorus-Therian', 'Ferrothorn', 'Heatran', 'Volcanion'),
('Victini', 'Tapu Koko', 'Weavile', 'Landorus-Therian', 'Tapu Fini', 'Ferrothorn'),
('Heatran', 'Tapu Fini', 'Dragonite', 'Landorus-Therian', 'Weavile', 'Kartana'),
('Zeraora', 'Nihilego', 'Celesteela', 'Heatran', 'Landorus-Therian', 'Tapu Fini'),
('Toxapex', 'Weavile', 'Corviknight', 'Rotom-Heat', 'Slowking-Galar', 'Landorus-Therian'),
('Weavile', 'Blacephalon', 'Zapdos', 'Ferrothorn', 'Landorus-Therian', 'Tapu Fini'),
('Garchomp', 'Tapu Fini', 'Melmetal', 'Necrozma', 'Zapdos', 'Weavile'),
('Tapu Koko', 'Volcanion', 'Ferrothorn', 'Tornadus-Therian', 'Toxapex', 'Landorus-Therian'),
('Heatran', 'Kartana', 'Landorus-Therian', 'Tapu Fini', 'Weavile', 'Zeraora'),
('Tapu Lele', 'Landorus-Therian', 'Corviknight', 'Tyranitar', 'Blacephalon', 'Toxapex'),
('Celesteela', 'Hawlucha', 'Rillaboom', 'Landorus-Therian', 'Zeraora', 'Urshifu-*'),
('Tapu Fini', 'Heatran', 'Landorus-Therian', 'Weavile', 'Nidoking', 'Dragonite'),
('Rillaboom', 'Magnezone', 'Clefable', 'Dragonite', 'Landorus-Therian', 'Tornadus-Therian'),
('Jirachi', 'Weavile', 'Tapu Lele', 'Magnezone', 'Landorus-Therian', 'Tapu Fini'),
('Nihilego', 'Kartana', 'Celesteela', 'Mew', 'Landorus-Therian', 'Urshifu-*'),
('Clefable', 'Dragonite', 'Ferrothorn', 'Landorus-Therian', 'Volcarona', 'Zeraora'),
('Pelipper', 'Scizor', 'Volcanion', 'Landorus-Therian', 'Melmetal', 'Kingdra'),
('Volcanion', 'Ninetales-Alola', 'Corviknight', 'Arctozolt', 'Landorus-Therian', 'Tornadus-Therian'),
('Volcanion', 'Ninetales-Alola', 'Corviknight', 'Arctozolt', 'Landorus-Therian', 'Tornadus-Therian'),
('Zapdos', 'Weavile', 'Kartana', 'Landorus-Therian', 'Volcanion', 'Melmetal'),
('Kartana', 'Tapu Fini', 'Moltres-Galar', 'Dragapult', 'Landorus-Therian', 'Volcarona'),
('Arctozolt', 'Ninetales-Alola', 'Weavile', 'Corviknight', 'Volcanion', 'Landorus-Therian'),
('Dragonite', 'Ferrothorn', 'Landorus-Therian', 'Rotom-Wash', 'Volcarona', 'Weavile'),
('Blacephalon', 'Weavile', 'Landorus-Therian', 'Ferrothorn', 'Rotom-Wash', 'Dragapult'),
('Ninetales-Alola', 'Heatran', 'Dragapult', 'Scizor', 'Garchomp', 'Cloyster'),
('Landorus-Therian', 'Rotom-Wash', 'Ferrothorn', 'Moltres-Galar', 'Weavile', 'Blacephalon'),
('Zeraora', 'Nihilego', 'Kartana', 'Heatran', 'Landorus-Therian', 'Tapu Fini'),
('Skarmory', 'Hippowdon', 'Tapu Koko', 'Reuniclus', 'Toxapex', 'Tornadus-Therian'),
('Weavile', 'Dragonite', 'Volcanion', 'Landorus-Therian', 'Ferrothorn', 'Tapu Fini'),
('Volcarona', 'Slowking', 'Kommo-o', 'Landorus-Therian', 'Tapu Koko', 'Kartana'),
('Landorus-Therian', 'Heatran', 'Ferrothorn', 'Clefable', 'Blacephalon', 'Weavile'),
('Tapu Koko', 'Weavile', 'Victini', 'Urshifu-*', 'Landorus-Therian', 'Ferrothorn'),
('Slowking-Galar', 'Landorus-Therian', 'Ferrothorn', 'Clefable', 'Rotom-Wash', 'Weavile'),
('Dragapult', 'Clefable', 'Heatran', 'Rotom-Wash', 'Melmetal', 'Landorus-Therian'),
('Gyarados', 'Heatran', 'Garchomp', 'Mew', 'Zapdos', 'Weavile'),
('Volcarona', 'Toxapex', 'Ferrothorn', 'Landorus-Therian', 'Weavile', 'Dragonite'),
('Garchomp', 'Buzzwole', 'Ferrothorn', 'Zapdos', 'Blacephalon', 'Tyranitar'),
('Magnezone', 'Tornadus-Therian', 'Landorus-Therian', 'Tapu Fini', 'Nihilego', 'Melmetal'),
('Zeraora', 'Nihilego', 'Landorus-Therian', 'Tapu Fini', 'Heatran', 'Celesteela'),
('Jirachi', 'Weavile', 'Magnezone', 'Landorus-Therian', 'Tapu Lele', 'Tapu Fini'),
('Slowking-Galar', 'Weavile', 'Landorus-Therian', 'Toxapex', 'Blacephalon', 'Corviknight'),
('Tapu Fini', 'Melmetal', 'Landorus-Therian', 'Dragapult', 'Buzzwole', 'Heatran'),
('Weavile', 'Landorus-Therian', 'Slowbro', 'Tornadus-Therian', 'Melmetal', 'Garchomp'),
('Volcanion', 'Tapu Lele', 'Weavile', 'Landorus-Therian', 'Ferrothorn', 'Dragonite'),
('Dragonite', 'Tapu Koko', 'Buzzwole', 'Heatran', 'Ferrothorn', 'Garchomp'),
('Ninetales-Alola', 'Arctozolt', 'Heatran', 'Garchomp', 'Blaziken', 'Dragapult'),
('Tyranitar', 'Corviknight', 'Tornadus-Therian', 'Hippowdon', 'Toxapex', 'Dracozolt'),
('Landorus-Therian', 'Volcanion', 'Ferrothorn', 'Heatran', 'Tornadus-Therian', 'Weavile'),
('Corviknight', 'Slowking-Galar', 'Weavile', 'Landorus-Therian', 'Toxapex', 'Blacephalon'),
('Slowking-Galar', 'Tornadus-Therian', 'Buzzwole', 'Hydreigon', 'Heatran', 'Zeraora'),
('Buzzwole', 'Clefable', 'Ferrothorn', 'Heatran', 'Rotom-Wash', 'Zeraora'),
('Urshifu-*', 'Tornadus-Therian', 'Slowking-Galar', 'Ferrothorn', 'Landorus-Therian', 'Tapu Fini'),
('Nidoking', 'Slowbro', 'Heatran', 'Landorus-Therian', 'Buzzwole', 'Zeraora'),
('Dragapult', 'Landorus-Therian', 'Weavile', 'Kartana', 'Melmetal', 'Blacephalon'),
('Rillaboom', 'Dragonite', 'Heatran', 'Mew', 'Landorus-Therian', 'Tapu Fini'),
('Buzzwole', 'Slowbro', 'Nidoking', 'Blissey', 'Corviknight', 'Zeraora'),
('Landorus-Therian', 'Ferrothorn', 'Tapu Koko', 'Dragonite', 'Buzzwole', 'Tapu Fini'),
('Weavile', 'Garchomp', 'Corviknight', 'Urshifu-*', 'Melmetal', 'Slowking-Galar'),
('Tapu Koko', 'Ferrothorn', 'Dragonite', 'Magnezone', 'Tapu Fini', 'Landorus-Therian'),
('Weavile', 'Garchomp', 'Volcarona', 'Zapdos', 'Tapu Fini', 'Ferrothorn'),
('Tapu Koko', 'Ferrothorn', 'Landorus-Therian', 'Tornadus-Therian', 'Tapu Fini', 'Buzzwole'),
('Tapu Fini', 'Melmetal', 'Dragapult', 'Buzzwole', 'Landorus-Therian', 'Heatran'),
('Nihilego', 'Tapu Fini', 'Ferrothorn', 'Landorus-Therian', 'Zapdos', 'Weavile'),
('Tyranitar', 'Excadrill', 'Buzzwole', 'Slowking', 'Tornadus-Therian', 'Volcanion'),
('Blacephalon', 'Tornadus-Therian', 'Slowking-Galar', 'Corviknight', 'Landorus-Therian', 'Toxapex'),
('Dragonite', 'Garchomp', 'Heatran', 'Ferrothorn', 'Tapu Koko', 'Buzzwole'),
('Slowking-Galar', 'Heatran', 'Tornadus-Therian', 'Landorus-Therian', 'Toxapex', 'Dragapult'),
('Tapu Koko', 'Dragonite', 'Victini', 'Ferrothorn', 'Landorus-Therian', 'Clefable'),
('Buzzwole', 'Clefable', 'Ferrothorn', 'Heatran', 'Rotom-Wash', 'Zeraora'),
('Tyranitar', 'Excadrill', 'Dracozolt', 'Landorus-Therian', 'Tornadus-Therian', 'Scizor'),
('Zapdos', 'Toxapex', 'Landorus-Therian', 'Weavile', 'Slowking-Galar', 'Scizor'),
('Clefable', 'Zapdos', 'Garchomp', 'Weavile', 'Ferrothorn', 'Tapu Fini'),
('Urshifu-*', 'Toxapex', 'Slowking-Galar', 'Landorus-Therian', 'Weavile', 'Corviknight'),
('Dragonite', 'Kartana', 'Landorus-Therian', 'Melmetal', 'Tapu Fini', 'Weavile'),
('Kartana', 'Weavile', 'Landorus-Therian', 'Melmetal', 'Dragapult', 'Dragonite'),
('Volcanion', 'Ninetales-Alola', 'Corviknight', 'Arctozolt', 'Landorus-Therian', 'Tornadus-Therian'),
('Jirachi', 'Weavile', 'Tapu Lele', 'Magnezone', 'Landorus-Therian', 'Tapu Fini'),
('Landorus-Therian', 'Volcanion', 'Ferrothorn', 'Heatran', 'Tornadus-Therian', 'Weavile'),
('Tapu Lele', 'Magnezone', 'Landorus-Therian', 'Volcanion', 'Weavile', 'Dragonite'),
('Toxapex', 'Tornadus-Therian', 'Heatran', 'Garchomp', 'Corviknight', 'Tapu Koko'),
('Tyranitar', 'Buzzwole', 'Excadrill', 'Volcanion', 'Tornadus-Therian', 'Slowking'),
('Landorus-Therian', 'Volcanion', 'Ferrothorn', 'Heatran', 'Tornadus-Therian', 'Weavile'),
('Weavile', 'Kartana', 'Landorus-Therian', 'Buzzwole', 'Heatran', 'Slowking'),
('Landorus-Therian', 'Urshifu-*', 'Aegislash', 'Ferrothorn', 'Weavile', 'Dragonite'),
('Volcanion', 'Ninetales-Alola', 'Corviknight', 'Arctozolt', 'Landorus-Therian', 'Tornadus-Therian'),
('Toxapex', 'Rhyperior', 'Tornadus-Therian', 'Slowbro', 'Tapu Koko', 'Heatran'),
('Garchomp', 'Corviknight', 'Landorus-Therian', 'Tapu Koko', 'Weavile', 'Toxapex'),
('Rotom-Wash', 'Clefable', 'Landorus-Therian', 'Kartana', 'Heatran', 'Weavile'),
('Garchomp', 'Weavile', 'Heatran', 'Tornadus-Therian', 'Tapu Fini', 'Kartana'),
('Zapdos', 'Toxapex', 'Landorus-Therian', 'Weavile', 'Slowking-Galar', 'Scizor'),
('Zeraora', 'Landorus-Therian', 'Heatran', 'Blacephalon', 'Tornadus-Therian', 'Tapu Fini'),
('Tornadus-Therian', 'Landorus-Therian', 'Slowbro', 'Melmetal', 'Garchomp', 'Weavile'),
('Volcanion', 'Ninetales-Alola', 'Corviknight', 'Arctozolt', 'Landorus-Therian', 'Tornadus-Therian'),
('Blacephalon', 'Landorus-Therian', 'Zapdos', 'Ferrothorn', 'Tapu Fini', 'Urshifu-*'),
('Ninetales-Alola', 'Dragapult', 'Heatran', 'Garchomp', 'Cloyster', 'Scizor'),
('Dragonite', 'Victini', 'Volcarona', 'Landorus-Therian', 'Kommo-o', 'Kartana'),
('Corviknight', 'Dragapult', 'Landorus-Therian', 'Mamoswine', 'Toxapex', 'Hydreigon'),
('Slowbro', 'Weavile', 'Heatran', 'Tornadus-Therian', 'Landorus-Therian', 'Melmetal'),
('Suicune', 'Ferrothorn', 'Landorus-Therian', 'Nihilego', 'Weavile', 'Dragapult'),
('Landorus-Therian', 'Corviknight', 'Volcanion', 'Ninetales-Alola', 'Arctozolt', 'Tornadus-Therian'),
('Ferrothorn', 'Clefable', 'Dragonite', 'Buzzwole', 'Landorus-Therian', 'Zapdos'),
('Scizor', 'Tornadus-Therian', 'Magnezone', 'Landorus-Therian', 'Kommo-o', 'Rotom-Wash'),
('Corviknight', 'Clefable', 'Tornadus-Therian', 'Toxapex', 'Dragonite', 'Gastrodon'),
('Tyranitar', 'Slowking', 'Tornadus-Therian', 'Excadrill', 'Buzzwole', 'Volcanion'),
('Weavile', 'Kartana', 'Landorus-Therian', 'Buzzwole', 'Heatran', 'Slowking'),
('Heatran', 'Tapu Fini', 'Kartana', 'Landorus-Therian', 'Hawlucha', 'Moltres-Galar'),
('Landorus-Therian', 'Corviknight', 'Ninetales-Alola', 'Arctozolt', 'Volcanion', 'Tornadus-Therian'),
('Nidoking', 'Dragonite', 'Shuckle', 'Zapdos-Galar', 'Bisharp', 'Kartana'),
('Weavile', 'Dragonite', 'Volcanion', 'Landorus-Therian', 'Ferrothorn', 'Tapu Fini'),
('Heatran', 'Rotom-Wash', 'Landorus-Therian', 'Ferrothorn', 'Weavile', 'Clefable'),
('Omastar', 'Clefable', 'Pelipper', 'Ferrothorn', 'Zapdos', 'Barraskewda'),
('Tornadus-Therian', 'Heatran', 'Landorus-Therian', 'Toxapex', 'Ferrothorn', 'Dragapult'),
('Weavile', 'Zapdos', 'Landorus-Therian', 'Dragonite', 'Clefable', 'Melmetal'),
('Buzzwole', 'Clefable', 'Ferrothorn', 'Heatran', 'Rotom-Wash', 'Zeraora'),
('Ninetales-Alola', 'Dragapult', 'Heatran', 'Garchomp', 'Cloyster', 'Scizor'),
('Landorus-Therian', 'Corviknight', 'Volcanion', 'Ninetales-Alola', 'Arctozolt', 'Tornadus-Therian'),
('Weavile', 'Blacephalon', 'Zapdos', 'Ferrothorn', 'Landorus-Therian', 'Tapu Fini'),
('Heatran', 'Rotom-Wash', 'Landorus-Therian', 'Ferrothorn', 'Weavile', 'Clefable'),
('Nidoking', 'Slowbro', 'Heatran', 'Landorus-Therian', 'Buzzwole', 'Zeraora'),
('Weavile', 'Landorus-Therian', 'Slowbro', 'Tornadus-Therian', 'Melmetal', 'Garchomp'),
('Garchomp', 'Necrozma', 'Keldeo', 'Kartana', 'Volcarona', 'Mew'),
('Weavile', 'Urshifu-*', 'Landorus-Therian', 'Corviknight', 'Magnezone', 'Slowking'),
('Mew', 'Cloyster', 'Volcarona', 'Garchomp', 'Bisharp', 'Zapdos-Galar'),
('Gengar', 'Heatran', 'Landorus-Therian', 'Tapu Koko', 'Ferrothorn', 'Hydreigon'),
('Urshifu-*', 'Slowking-Galar', 'Buzzwole', 'Landorus-Therian', 'Heatran', 'Weavile'),
('Nidoking', 'Corviknight', 'Slowbro', 'Blissey', 'Zeraora', 'Buzzwole'),
('Clefable', 'Weavile', 'Landorus-Therian', 'Tapu Koko', 'Heatran', 'Slowbro'),
('Landorus-Therian', 'Ferrothorn', 'Tapu Koko', 'Dragonite', 'Buzzwole', 'Volcarona'),
('Clefable', 'Slowking', 'Landorus-Therian', 'Buzzwole', 'Zeraora', 'Melmetal'),
('Slowking', 'Nidoking', 'Ferrothorn', 'Landorus-Therian', 'Tapu Koko', 'Buzzwole'),
('Skarmory', 'Hippowdon', 'Tapu Koko', 'Reuniclus', 'Toxapex', 'Tornadus-Therian'),
('Weavile', 'Landorus-Therian', 'Volcanion', 'Tapu Koko', 'Buzzwole', 'Kartana'),
('Tapu Lele', 'Magnezone', 'Landorus-Therian', 'Volcanion', 'Weavile', 'Dragonite'),
('Slowking', 'Ferrothorn', 'Landorus-Therian', 'Tapu Lele', 'Buzzwole', 'Dragapult'),
('Kartana', 'Clefable', 'Landorus-Therian', 'Heatran', 'Rotom-Wash', 'Dragonite'),
('Landorus-Therian', 'Ferrothorn', 'Tapu Koko', 'Dragonite', 'Buzzwole', 'Tapu Fini'),
('Aegislash', 'Shuckle', 'Dragonite', 'Tapu Koko', 'Blastoise', 'Diggersby'),
('Tapu Koko', 'Landorus-Therian', 'Volcanion', 'Kartana', 'Weavile', 'Buzzwole'),
('Buzzwole', 'Clefable', 'Zeraora', 'Slowking-Galar', 'Dragonite', 'Ferrothorn'),
('Kartana', 'Heatran', 'Landorus-Therian', 'Zapdos-Galar', 'Toxapex', 'Weavile'),
('Rotom-Wash', 'Blacephalon', 'Buzzwole', 'Landorus-Therian', 'Heatran', 'Dragapult'),
('Tapu Lele', 'Heatran', 'Landorus-Therian', 'Tapu Fini', 'Weavile', 'Dragonite'),
('Blaziken', 'Landorus-Therian', 'Nihilego', 'Celesteela', 'Kartana', 'Urshifu-*'),
('Dragonite', 'Tapu Koko', 'Buzzwole', 'Heatran', 'Ferrothorn', 'Garchomp'),
('Tapu Koko', 'Ferrothorn', 'Nidoking', 'Buzzwole', 'Slowking', 'Landorus-Therian'),
('Kartana', 'Urshifu-*', 'Landorus-Therian', 'Rillaboom', 'Heatran', 'Zapdos'),
('Landorus-Therian', 'Ferrothorn', 'Tapu Lele', 'Alakazam', 'Moltres-Galar', 'Rotom-Wash'),
('Magnezone', 'Tornadus-Therian', 'Landorus-Therian', 'Tapu Lele', 'Tapu Fini', 'Nihilego'),
('Rotom-Wash', 'Buzzwole', 'Heatran', 'Landorus-Therian', 'Dragapult', 'Slowbro'),
('Tyranitar', 'Landorus-Therian', 'Toxapex', 'Tapu Lele', 'Blacephalon', 'Corviknight'),
('Landorus-Therian', 'Tapu Fini', 'Jirachi', 'Magnezone', 'Weavile', 'Tapu Lele'),
('Dragapult', 'Landorus-Therian', 'Weavile', 'Kartana', 'Blacephalon', 'Melmetal'),
('Tornadus-Therian', 'Buzzwole', 'Corviknight', 'Blissey', 'Gastrodon', 'Toxapex'),
('Landorus-Therian', 'Tapu Lele', 'Magnezone', 'Volcanion', 'Weavile', 'Dragonite'),
('Tapu Lele', 'Espeon', 'Polteageist', 'Omastar', 'Cloyster', 'Hawlucha'),
('Weavile', 'Toxapex', 'Urshifu-*', 'Slowking-Galar', 'Landorus-Therian', 'Corviknight'),
('Rotom-Wash', 'Clefable', 'Skarmory', 'Heatran', 'Slowking-Galar', 'Krookodile'),
('Tapu Lele', 'Blacephalon', 'Tyranitar', 'Landorus-Therian', 'Corviknight', 'Toxapex'),
('Nihilego', 'Celesteela', 'Garchomp', 'Zapdos-Galar', 'Tapu Fini', 'Kartana'),
('Slowbro', 'Weavile', 'Heatran', 'Tornadus-Therian', 'Landorus-Therian', 'Melmetal'),
('Buzzwole', 'Slowking-Galar', 'Zeraora', 'Landorus-Therian', 'Heatran', 'Rotom-Wash'),
('Dragapult', 'Urshifu-*', 'Zapdos', 'Heatran', 'Slowking', 'Landorus-Therian'),
('Blacephalon', 'Weavile', 'Corviknight', 'Garchomp', 'Slowking-Galar', 'Urshifu-*'),
('Buzzwole', 'Clefable', 'Ferrothorn', 'Heatran', 'Rotom-Wash', 'Zeraora'),
('Melmetal', 'Garchomp', 'Weavile', 'Urshifu-*', 'Slowking-Galar', 'Corviknight'),
('Corviknight', 'Buzzwole', 'Gastrodon', 'Tornadus-Therian', 'Blissey', 'Toxapex'),
('Slowking-Galar', 'Heatran', 'Tornadus-Therian', 'Buzzwole', 'Zeraora', 'Urshifu-*'),
('Weavile', 'Heatran', 'Landorus-Therian', 'Tapu Lele', 'Tapu Fini', 'Dragapult'),
('Ferrothorn', 'Weavile', 'Heatran', 'Slowbro', 'Landorus-Therian', 'Zeraora'),
('Landorus-Therian', 'Ferrothorn', 'Tapu Koko', 'Dragonite', 'Clefable', 'Volcarona'),
('Dragonite', 'Jirachi', 'Weavile', 'Volcarona', 'Landorus-Therian', 'Kartana'),
('Rotom-Wash', 'Dragapult', 'Ferrothorn', 'Blacephalon', 'Weavile', 'Landorus-Therian'),
('Tapu Koko', 'Weavile', 'Garchomp', 'Landorus-Therian', 'Heatran', 'Tapu Fini'),
('Clefable', 'Weavile', 'Landorus-Therian', 'Tapu Koko', 'Heatran', 'Slowbro'),
('Tapu Koko', 'Kartana', 'Dragonite', 'Landorus-Therian', 'Heatran', 'Clefable'),
('Garchomp', 'Tornadus-Therian', 'Heatran', 'Clefable', 'Rotom-Wash', 'Weavile'),
('Excadrill', 'Tyranitar', 'Clefable', 'Tornadus-Therian', 'Rotom-Wash', 'Volcarona'),
('Blissey', 'Slowking-Galar', 'Corviknight', 'Toxapex', 'Clefable', 'Gastrodon'),
('Landorus-Therian', 'Ferrothorn', 'Dragonite', 'Tapu Koko', 'Clefable', 'Weavile'),
('Zapdos', 'Clefable', 'Hydreigon', 'Toxapex', 'Ferrothorn', 'Zeraora'),
('Ninetales-Alola', 'Dragapult', 'Heatran', 'Garchomp', 'Scizor', 'Arctozolt'),
('Landorus-Therian', 'Weavile', 'Heatran', 'Tapu Fini', 'Buzzwole', 'Dragapult'),
('Zeraora', 'Tapu Fini', 'Heatran', 'Kartana', 'Garchomp', 'Landorus-Therian'),
('Skarmory', 'Blissey', 'Gastrodon', 'Reuniclus', 'Toxapex', 'Tapu Koko'),
('Clefable', 'Slowking-Galar', 'Skarmory', 'Gastrodon', 'Heatran', 'Tapu Koko'),
('Ferrothorn', 'Volcarona', 'Tapu Koko', 'Landorus-Therian', 'Clefable', 'Dragonite'),
('Landorus-Therian', 'Heatran', 'Clefable', 'Hydreigon', 'Ferrothorn', 'Tapu Koko'),
('Landorus-Therian', 'Heatran', 'Slowking', 'Weavile', 'Buzzwole', 'Blacephalon'),
('Heatran', 'Blacephalon', 'Landorus-Therian', 'Weavile', 'Tapu Fini', 'Kartana')
]

itemsets, rules = apriori(trans, min_support=0.01, min_confidence=0.01, max_length=6)

# %%
for k, v in itemsets.items():
  print("team of ", k)
  print(v)
# Out:
# team of  1
# ...
